# %% [markdown]
# # Import packages

# %%
import os, pandas as pd, sklearn, arff, pprint, numpy as np, seaborn as sns
from sklearn import neighbors
from tqdm import tqdm
# import missingno as msno
from sklearn.model_selection import StratifiedShuffleSplit
import warnings

import openml
from openml import datasets
from openml.datasets import get_dataset # edit_dataset, fork_dataset
from openml.tasks import TaskType
openml.config.apikey = '2474cbc06507fbf9677530945039be25'
openml.config.server = 'https://www.openml.org/api/v1' # https://test.openml.org/api/v1/xml
openml.config.set_cache_directory(os.path.expanduser('~/openml/cache'))
openml.config.cachedir = '~/openml/cache'

# %% [markdown]
# # 1. OpenML-CC18 (SCARF)
# - Out of 72 datasets,
#     - Exclude image datasets: mnist_784, Fashion-MNIST, CIFAR_10 (69 left)
#     - Exclude the ones without categorical variables (23 left)

# %%
benchmark_suite = openml.study.get_suite(suite_id=99)
benchmark_suite = openml.study.get_suite(suite_id='OpenML-CC18')
benchmark_suite
# Out:
# OpenML Benchmark Suite
# ======================
# ID..............: 99
# Name............: OpenML-CC18 Curated Classification benchmark
# Status..........: active
# Main Entity Type: task
# Study URL.......: https://www.openml.org/s/99
# # of Data.......: 72
# # of Tasks......: 72
# Creator.........: https://www.openml.org/u/1
# Upload Time.....: 2019-02-21 18:47:13

# %%
# Task IDs and data IDs present in the benchmark suite.

print('number of tasks:', len(benchmark_suite.tasks))
print('task ids:', benchmark_suite.tasks)
print('')
print('number of data:', len(benchmark_suite.data))
print('data ids:', benchmark_suite.data)
# Out:
# number of tasks: 72
# task ids: [3, 6, 11, 12, 14, 15, 16, 18, 22, 23, 28, 29, 31, 32, 37, 43, 45, 49, 53, 219, 2074, 2079, 3021, 3022, 3481, 3549, 3560, 3573, 3902, 3903, 3904, 3913, 3917, 3918, 7592, 9910, 9946, 9952, 9957, 9960, 9964, 9971, 9976, 9977, 9978, 9981, 9985, 10093, 10101, 14952, 14954, 14965, 14969, 14970, 125920, 125922, 146195, 146800, 146817, 146819, 146820, 146821, 146822, 146824, 146825, 167119, 167120, 167121, 167124, 167125, 167140, 167141]
#
# number of data: 72
# data ids: [3, 6, 11, 12, 14, 15, 16, 18, 22, 23, 28, 29, 31, 32, 37, 44, 46, 50, 54, 151, 182, 188, 38, 307, 300, 458, 469, 554, 1049, 1050, 1053, 1063, 1067, 1068, 1590, 4134, 1510, 1489, 1494, 1497, 1501, 1480, 1485, 1486, 1487, 1468, 1475, 1462, 1464, 4534, 6332, 1461, 4538, 1478, 23381, 40499, 40668, 40966, 40982, 40994, 40983, 40975, 40984, 40979, 40996, 41027, 23517, 40923, 40927, 40978, 40670, 40701]

# %%
data_ids_1 = benchmark_suite.data

# %%
"""
Get datasets
"""

dlist = openml.datasets.list_datasets(data_id=benchmark_suite.data, output_format='dataframe')

# drop rows where 'name' contains 'mnist' or 'MNIST' or 'CIFAR'
dlist = dlist[~dlist['name'].str.contains('mnist', case=False)]
dlist = dlist[~dlist['name'].str.contains('MNIST', case=False)]
dlist = dlist[~dlist['name'].str.contains('CIFAR', case=False)]

dlist
# Out:
#          did                                    name  version uploader  \
# 3          3                                kr-vs-kp        1        1
# 6          6                                  letter        1        1
# 11        11                           balance-scale        1        1
# 12        12                           mfeat-factors        1        1
# 14        14                           mfeat-fourier        1        1
# ...      ...                                     ...      ...      ...
# 40982  40982                      steel-plates-fault        3     4265
# 40983  40983                                    wilt        2     4265
# 40984  40984                                 segment        3     4265
# 40994  40994        climate-model-simulation-crashes        4     4265
# 41027  41027  jungle_chess_2pcs_raw_endgame_complete        1        1
#
#        status format  MajorityClassSize  MaxNominalAttDistinctValues  \
# 3      active   ARFF             1669.0                          3.0
# 6      active   ARFF              813.0                         26.0
# 11     active   ARFF              288.0                          3.0
# 12     active   ARFF              200.0                         10.0
# 14     active   ARFF              200.0                         10.0
# ...       ...    ...                ...                          ...
# 40982  active   ARFF              673.0                          7.0
# 40983  active   ARFF             4578.0                          2.0
# 40984  active   ARFF              330.0                          7.0
# 40994  active   ARFF              494.0                          2.0
# 41027  active   arff            23062.0                          3.0
#
#        MinorityClassSize  NumberOfClasses  NumberOfFeatures  \
# 3                 1527.0              2.0              37.0
# 6                  734.0             26.0              17.0
# 11                  49.0              3.0               5.0
# 12                 200.0             10.0             217.0
# 14                 200.0             10.0              77.0
# ...                  ...              ...               ...
# 40982               55.0              7.0              28.0
# 40983              261.0              2.0               6.0
# 40984              330.0              7.0              20.0
# 40994               46.0              2.0              21.0
# 41027             4335.0              3.0               7.0
#
#        NumberOfInstances  NumberOfInstancesWithMissingValues  \
# 3                 3196.0                                 0.0
# 6                20000.0                                 0.0
# 11                 625.0                                 0.0
# 12                2000.0                                 0.0
# 14                2000.0                                 0.0
# ...                  ...                                 ...
# 40982             1941.0                                 0.0
# 40983             4839.0                                 0.0
# 40984             2310.0                                 0.0
# 40994              540.0                                 0.0
# 41027            44819.0                                 0.0
#
#        NumberOfMissingValues  NumberOfNumericFeatures  \
# 3                        0.0                      0.0
# 6                        0.0                     16.0
# 11                       0.0                      4.0
# 12                       0.0                    216.0
# 14                       0.0                     76.0
# ...                      ...                      ...
# 40982                    0.0                     27.0
# 40983                    0.0                      5.0
# 40984                    0.0                     19.0
# 40994                    0.0                     20.0
# 41027                    0.0                      6.0
#
#        NumberOfSymbolicFeatures
# 3                          37.0
# 6                           1.0
# 11                          1.0
# 12                          1.0
# 14                          1.0
# ...                         ...
# 40982                       1.0
# 40983                       1.0
# 40984                       1.0
# 40994                       1.0
# 41027                       1.0
#
# [69 rows x 16 columns]

# %%
"""
Count the number of data with both 'continuous' and 'categorical' variables, and the number of data with only 'categorical' variables.
"""

# see if NumberOfFeatures == NumberOfNumericFeatures + NumberOfSymbolicFeatures
# count the number of False, if any
temp = dlist['NumberOfFeatures'] == dlist['NumberOfNumericFeatures'] + dlist['NumberOfSymbolicFeatures']
print(temp.value_counts())

# count the number of rows where 'NumberOfNumericFeatures' or 'NumberOfSymbolicFeatures' is zero
print('number of rows where NumberOfNumericFeatures is zero:', len(dlist[dlist['NumberOfNumericFeatures'] == 0]))
# NumberOfSymbolicFeatures includes the class, so if it's 1, it means there's no categorical variable.
print('number of rows where NumberOfSymbolicFeatures is one:', len(dlist[dlist['NumberOfSymbolicFeatures'] == 1]))
# Out:
# True    69
# dtype: int64
# number of rows where NumberOfNumericFeatures is zero: 8
# number of rows where NumberOfSymbolicFeatures is one: 45

# %%
# Get tasks

tlist = openml.tasks.list_tasks(tag="OpenML-CC18", output_format="dataframe")
tlist = openml.tasks.list_tasks(task_id=benchmark_suite.tasks, output_format="dataframe")
tlist
# Out:
#            tid                                ttid    did  \
# 3            3  TaskType.SUPERVISED_CLASSIFICATION      3
# 6            6  TaskType.SUPERVISED_CLASSIFICATION      6
# 11          11  TaskType.SUPERVISED_CLASSIFICATION     11
# 12          12  TaskType.SUPERVISED_CLASSIFICATION     12
# 14          14  TaskType.SUPERVISED_CLASSIFICATION     14
# ...        ...                                 ...    ...
# 167121  167121  TaskType.SUPERVISED_CLASSIFICATION  40923
# 167124  167124  TaskType.SUPERVISED_CLASSIFICATION  40927
# 167125  167125  TaskType.SUPERVISED_CLASSIFICATION  40978
# 167140  167140  TaskType.SUPERVISED_CLASSIFICATION  40670
# 167141  167141  TaskType.SUPERVISED_CLASSIFICATION  40701
#
#                            name                  task_type  status  \
# 3                      kr-vs-kp  Supervised Classification  active
# 6                        letter  Supervised Classification  active
# 11                balance-scale  Supervised Classification  active
# 12                mfeat-factors  Supervised Classification  active
# 14                mfeat-fourier  Supervised Classification  active
# ...                         ...                        ...     ...
# 167121         Devnagari-Script  Supervised Classification  active
# 167124                 CIFAR_10  Supervised Classification  active
# 167125  Internet-Advertisements  Supervised Classification  active
# 167140                      dna  Supervised Classification  active
# 167141                    churn  Supervised Classification  active
#
#            estimation_procedure source_data target_feature  MajorityClassSize  \
# 3       10-fold Crossvalidation           3          class               1669
# 6       10-fold Crossvalidation           6          class                813
# 11      10-fold Crossvalidation          11          class                288
# 12      10-fold Crossvalidation          12          class                200
# 14      10-fold Crossvalidation          14          class                200
# ...                         ...         ...            ...                ...
# 167121  10-fold Crossvalidation       40923      character               2000
# 167124  10-fold Crossvalidation       40927          class               6000
# 167125  10-fold Crossvalidation       40978          class               2820
# 167140  10-fold Crossvalidation       40670          class               1654
# 167141  10-fold Crossvalidation       40701          class               4293
#
#         MaxNominalAttDistinctValues  MinorityClassSize  NumberOfClasses  \
# 3                               3.0               1527                2
# 6                              26.0                734               26
# 11                              3.0                 49                3
# 12                             10.0                200               10
# 14                             10.0                200               10
# ...                             ...                ...              ...
# 167121                         46.0               2000               46
# 167124                         10.0               6000               10
# 167125                          2.0                459                2
# 167140                          3.0                765                3
# 167141                         10.0                707                2
#
#         NumberOfFeatures  NumberOfInstances  \
# 3                     37               3196
# 6                     17              20000
# 11                     5                625
# 12                   217               2000
# 14                    77               2000
# ...                  ...                ...
# 167121              1025              92000
# 167124              3073              60000
# 167125              1559               3279
# 167140               181               3186
# 167141                21               5000
#
#         NumberOfInstancesWithMissingValues  NumberOfMissingValues  \
# 3                                        0                      0
# 6                                        0                      0
# 11                                       0                      0
# 12                                       0                      0
# 14                                       0                      0
# ...                                    ...                    ...
# 167121                                   0                      0
# 167124                                   0                      0
# 167125                                   0                      0
# 167140                                   0                      0
# 167141                                   0                      0
#
#         NumberOfNumericFeatures  NumberOfSymbolicFeatures
# 3                             0                        37
# 6                            16                         1
# 11                            4                         1
# 12                          216                         1
# 14                           76                         1
# ...                         ...                       ...
# 167121                     1024                         1
# 167124                     3072                         1
# 167125                        3                      1556
# 167140                        0                       181
# 167141                       16                         5
#
# [72 rows x 19 columns]

# %% [markdown]
# ## Collect

# %%
current_dir = os.getcwd()
save_path = current_dir + '/data/data_1/'

print(save_path)
# Out:
# c:\Users\lesga\OneDrive\문서\JupyterLab\연구_SSLT\Dataset_OpenML/data/data_1/

# %%
dataset_dict = {}
did_SCARF = []

for did in tqdm(dlist['did']):
    # get dataset name from dlist
    name = dlist.loc[dlist['did']==did, 'name'].values[0]
    
    # get dataset from dlist
    odata = openml.datasets.get_dataset(did)
    X, y, categorical_indicator, attribute_names = odata.get_data(
                                                            target=odata.default_target_attribute, 
                                                            include_row_id=True,
                                                            include_ignore_attribute=True,
    )
    y.name = 'class' # the name of the 'y' variable
    
    if True in categorical_indicator: # Only data with categorical variables.
        
        # collect did
        did_SCARF.append(did)
        
        # get num, cat feature names
        num_feat_names = [attribute_names[i] for i in range(len(attribute_names)) if categorical_indicator[i]==False]
        cat_feat_names = [attribute_names[i] for i in range(len(attribute_names)) if categorical_indicator[i]==True]

        if len(num_feat_names) != 0: # Only data with continuous variables.

            # sort features names by num_feat_names and cat_feat_names
            X = X[num_feat_names+cat_feat_names] 
            # remove columns if cardinality is one
            X = X.loc[:, X.nunique() != 1]
            # remove columns if cardinality is num of rows (id)
            X = X.loc[:, X.nunique() != X.shape[0]]

            # get split from tlist
            task = openml.tasks.get_task(tlist[tlist['did']==did]['tid'].values[0])
            train_indices, test_indices = task.get_train_test_split_indices(repeat=0, fold=0, sample=0,)
            X_train, X_test, y_train, y_test = X.iloc[train_indices], X.iloc[test_indices], y.iloc[train_indices], y.iloc[test_indices]
            train = pd.concat([X_train, y_train], axis=1)
            test = pd.concat([X_test, y_test], axis=1)

            # create a folder path
            os.makedirs(save_path+f'{did}-{name}', exist_ok=True)
            # save train and test data
            train.to_csv(save_path+f'{did}-{name}/train.csv', index=False)
            test.to_csv(save_path+f'{did}-{name}/test.csv', index=False)
            
            # save cat feat names
            pd.DataFrame(cat_feat_names).to_csv(save_path+f'{did}-{name}/cat_feat_names.csv', index=False)
# Out:
# 100%|██████████| 69/69 [08:22<00:00,  7.29s/it]
# 15

# %% [markdown]
# # 2. Why do tree-based models still outperform deep learning on tabular data?

# %%
# Categorical classification, OpenML benchmark
# https://www.openml.org/search?type=benchmark&sort=tasks_included&study_type=task&id=300

# %%
benchmark_suite = openml.study.get_suite(suite_id = 300)
benchmark_suite
# Out:
# OpenML Benchmark Suite
# ======================
# ID..............: 300
# Name............: Tabular benchmark categorical classification
# Status..........: in_preparation
# Main Entity Type: task
# Study URL.......: https://www.openml.org/s/300
# # of Data.......: 7
# # of Tasks......: 7
# Creator.........: https://www.openml.org/u/26324
# Upload Time.....: 2022-07-12 18:58:05

# %%
# Task IDs and data IDs present in the benchmark suite.

print('number of tasks:', len(benchmark_suite.tasks))
print('task ids:', benchmark_suite.tasks)
print('')
print('number of data:', len(benchmark_suite.data))
print('data ids:', benchmark_suite.data)
# Out:
# number of tasks: 7
# task ids: [361110, 361111, 361112, 361113, 361114, 361115, 361116]
#
# number of data: 7
# data ids: [44156, 44157, 44158, 44159, 44160, 44161, 44162]

# %%
data_ids_2 = benchmark_suite.data

# %%
"""
Get datasets
"""

dlist = datasets.list_datasets(data_id=benchmark_suite.data, output_format='dataframe')
dlist
# Out:
#          did                name  version uploader  status format  \
# 44156  44156         electricity       13    26324  active   arff
# 44157  44157       eye_movements        8    26324  active   arff
# 44158  44158  KDDCup09_upselling        4    26324  active   arff
# 44159  44159           covertype       13    26324  active   arff
# 44160  44160                  rl        4    26324  active   arff
# 44161  44161         road-safety        6    26324  active   arff
# 44162  44162             compass        3    26324  active   arff
#
#        MajorityClassSize  MinorityClassSize  NumberOfClasses  \
# 44156            19237.0            19237.0              2.0
# 44157             3804.0             3804.0              2.0
# 44158             2516.0             2516.0              2.0
# 44159           211840.0           211840.0              2.0
# 44160             2485.0             2485.0              2.0
# 44161            55881.0            55881.0              2.0
# 44162             8322.0             8322.0              2.0
#
#        NumberOfFeatures  NumberOfInstances  \
# 44156               9.0            38474.0
# 44157              24.0             7608.0
# 44158              46.0             5032.0
# 44159              55.0           423680.0
# 44160              13.0             4970.0
# 44161              33.0           111762.0
# 44162              18.0            16644.0
#
#        NumberOfInstancesWithMissingValues  NumberOfMissingValues  \
# 44156                                 0.0                    0.0
# 44157                                 0.0                    0.0
# 44158                                 0.0                    0.0
# 44159                                 0.0                    0.0
# 44160                                 0.0                    0.0
# 44161                                 0.0                    0.0
# 44162                                 0.0                    0.0
#
#        NumberOfNumericFeatures  NumberOfSymbolicFeatures
# 44156                      7.0                       2.0
# 44157                     20.0                       4.0
# 44158                     34.0                      12.0
# 44159                     10.0                      45.0
# 44160                      5.0                       8.0
# 44161                     29.0                       4.0
# 44162                      8.0                      10.0

# %%
"""
Count the number of data with both 'continuous' and 'categorical' variables, and the number of data with only 'categorical' variables.
"""


# see if NumberOfFeatures == NumberOfNumericFeatures + NumberOfSymbolicFeatures
# count the number of False, if any
temp = dlist['NumberOfFeatures'] == dlist['NumberOfNumericFeatures'] + dlist['NumberOfSymbolicFeatures']
print(temp.value_counts())

# count the number of rows where 'NumberOfNumericFeatures' or 'NumberOfSymbolicFeatures' is zero
print('number of rows where NumberOfNumericFeatures is zero:', len(dlist[dlist['NumberOfNumericFeatures'] == 0]))
# NumberOfSymbolicFeatures includes the class, so if it's 1, it means there's no categorical variable.
print('number of rows where NumberOfSymbolicFeatures is one:', len(dlist[dlist['NumberOfSymbolicFeatures'] == 1]))
# Out:
# True    7
# dtype: int64
# number of rows where NumberOfNumericFeatures is zero: 0
# number of rows where NumberOfSymbolicFeatures is one: 0

# %%
# Get tasks

tlist = openml.tasks.list_tasks(task_id=benchmark_suite.tasks, output_format="dataframe")
tlist
# Out:
#            tid                                ttid    did                name  \
# 361110  361110  TaskType.SUPERVISED_CLASSIFICATION  44156         electricity
# 361111  361111  TaskType.SUPERVISED_CLASSIFICATION  44157       eye_movements
# 361112  361112  TaskType.SUPERVISED_CLASSIFICATION  44158  KDDCup09_upselling
# 361113  361113  TaskType.SUPERVISED_CLASSIFICATION  44159           covertype
# 361114  361114  TaskType.SUPERVISED_CLASSIFICATION  44160                  rl
# 361115  361115  TaskType.SUPERVISED_CLASSIFICATION  44161         road-safety
# 361116  361116  TaskType.SUPERVISED_CLASSIFICATION  44162             compass
#
#                         task_type  status     estimation_procedure  \
# 361110  Supervised Classification  active  10-fold Crossvalidation
# 361111  Supervised Classification  active  10-fold Crossvalidation
# 361112  Supervised Classification  active  10-fold Crossvalidation
# 361113  Supervised Classification  active  10-fold Crossvalidation
# 361114  Supervised Classification  active  10-fold Crossvalidation
# 361115  Supervised Classification  active  10-fold Crossvalidation
# 361116  Supervised Classification  active  10-fold Crossvalidation
#
#         evaluation_measures source_data target_feature  MajorityClassSize  \
# 361110  predictive_accuracy       44156          class              19237
# 361111  predictive_accuracy       44157          label               3804
# 361112  predictive_accuracy       44158      UPSELLING               2516
# 361113  predictive_accuracy       44159          class             211840
# 361114  predictive_accuracy       44160          class               2485
# 361115  predictive_accuracy       44161  Sex_of_Driver              55881
# 361116  predictive_accuracy       44162       is_recid               8322
#
#         MinorityClassSize  NumberOfClasses  NumberOfFeatures  \
# 361110              19237                2                 9
# 361111               3804                2                24
# 361112               2516                2                46
# 361113             211840                2                55
# 361114               2485                2                13
# 361115              55881                2                33
# 361116               8322                2                18
#
#         NumberOfInstances  NumberOfInstancesWithMissingValues  \
# 361110              38474                                   0
# 361111               7608                                   0
# 361112               5032                                   0
# 361113             423680                                   0
# 361114               4970                                   0
# 361115             111762                                   0
# 361116              16644                                   0
#
#         NumberOfMissingValues  NumberOfNumericFeatures  \
# 361110                      0                        7
# 361111                      0                       20
# 361112                      0                       34
# 361113                      0                       10
# 361114                      0                        5
# 361115                      0                       29
# 361116                      0                        8
#
#         NumberOfSymbolicFeatures
# 361110                         2
# 361111                         4
# 361112                        12
# 361113                        45
# 361114                         8
# 361115                         4
# 361116                        10

# %% [markdown]
# ## Collect

# %%
current_dir = os.getcwd()
save_path = current_dir + '/data/data_2/'

print(save_path)
# Out:
# /home/ubuntu/User/LEE/연구_신한/Dataset_OpenML/data/data_2/

# %%
dataset_dict = {}
did_trees = []

for did in tqdm(dlist['did']):
    # get dataset name from dlist
    name = dlist.loc[dlist['did']==did, 'name'].values[0]
    
    # get dataset from dlist
    odata = openml.datasets.get_dataset(did)
    X, y, categorical_indicator, attribute_names = odata.get_data(
                                                            target=odata.default_target_attribute, 
                                                            include_row_id=True,
                                                            include_ignore_attribute=True,
    )
    y.name = 'class' # the name of the 'y' variable
    
    if True in categorical_indicator: # Only data with categorical variables.
        
        # collect did
        did_trees.append(did)
        
        # get num, cat feature names
        num_feat_names = [attribute_names[i] for i in range(len(attribute_names)) if categorical_indicator[i]==False]
        cat_feat_names = [attribute_names[i] for i in range(len(attribute_names)) if categorical_indicator[i]==True]

        # sort features names by num_feat_names and cat_feat_names
        X = X[num_feat_names+cat_feat_names] 
        # remove columns if cardinality is one
        X = X.loc[:, X.nunique() != 1]
        # remove columns if cardinality is num of rows (id)
        X = X.loc[:, X.nunique() != X.shape[0]]

        # get split from tlist
        task = openml.tasks.get_task(tlist[tlist['did']==did]['tid'].values[0])
        train_indices, test_indices = task.get_train_test_split_indices(repeat=0, fold=0, sample=0,)
        X_train, X_test, y_train, y_test = X.iloc[train_indices], X.iloc[test_indices], y.iloc[train_indices], y.iloc[test_indices]
        train = pd.concat([X_train, y_train], axis=1)
        test = pd.concat([X_test, y_test], axis=1)
        
        # create a folder path
        os.makedirs(save_path+f'{did}-{name}', exist_ok=True)
        # save train and test data
        train.to_csv(save_path+f'{did}-{name}/train.csv', index=False)
        test.to_csv(save_path+f'{did}-{name}/test.csv', index=False)
        
        # save cat feat names
        pd.DataFrame(cat_feat_names).to_csv(save_path+f'{did}-{name}/cat_feat_names.csv', index=False)
# Out:
# 100%|██████████| 7/7 [00:33<00:00,  4.72s/it]

# %%
# Numerical classification, OpenML benchmark
# https://www.openml.org/search?type=benchmark&study_type=task&sort=tasks_included&id=298

# %%
benchmark_suite = openml.study.get_suite(suite_id = 298)
benchmark_suite
# Out:
# OpenML Benchmark Suite
# ======================
# ID..............: 298
# Name............: Tabular benchmark numerical classification
# Status..........: in_preparation
# Main Entity Type: task
# Study URL.......: https://www.openml.org/s/298
# # of Data.......: 15
# # of Tasks......: 15
# Creator.........: https://www.openml.org/u/26324
# Upload Time.....: 2022-07-10 11:00:56

# %%
# Task IDs and data IDs present in the benchmark suite.

print('number of tasks:', len(benchmark_suite.tasks))
print('task ids:', benchmark_suite.tasks)
print('')
print('number of data:', len(benchmark_suite.data))
print('data ids:', benchmark_suite.data)
# Out:
# number of tasks: 15
# task ids: [361055, 361056, 361057, 361060, 361061, 361062, 361063, 361064, 361065, 361066, 361067, 361068, 361069, 361070, 361071]
#
# number of data: 15
# data ids: [44089, 44090, 44091, 44120, 44121, 44122, 44123, 44124, 44125, 44126, 44127, 44128, 44129, 44130, 44131]

# %%
data_ids_3 = benchmark_suite.data

# %%
"""
Get datasets
"""

dlist = datasets.list_datasets(data_id=benchmark_suite.data, output_format='dataframe')
dlist
# Out:
#          did                   name  version uploader  status format  \
# 44089  44089                 credit        2    26324  active   arff
# 44090  44090             california        5    26324  active   arff
# 44091  44091                   wine        8    26324  active   arff
# 44120  44120            electricity       12    26324  active   arff
# 44121  44121              covertype       12    26324  active   arff
# 44122  44122                    pol       10    26324  active   arff
# 44123  44123              house_16H       10    26324  active   arff
# 44124  44124  kdd_ipums_la_97-small        6    26324  active   arff
# 44125  44125         MagicTelescope        7    26324  active   arff
# 44126  44126         bank-marketing        8    26324  active   arff
# 44127  44127                phoneme        7    26324  active   arff
# 44128  44128              MiniBooNE        6    26324  active   arff
# 44129  44129                  Higgs        7    26324  active   arff
# 44130  44130          eye_movements        7    26324  active   arff
# 44131  44131                 jannis        5    26324  active   arff
#
#        MajorityClassSize  MinorityClassSize  NumberOfClasses  \
# 44089             8357.0             8357.0              2.0
# 44090            10317.0            10317.0              2.0
# 44091             1277.0             1277.0              2.0
# 44120            19237.0            19237.0              2.0
# 44121           283301.0           283301.0              2.0
# 44122             5041.0             5041.0              2.0
# 44123             6744.0             6744.0              2.0
# 44124             2594.0             2594.0              2.0
# 44125             6688.0             6688.0              2.0
# 44126             5289.0             5289.0              2.0
# 44127             1586.0             1586.0              2.0
# 44128            36499.0            36499.0              2.0
# 44129           470080.0           470080.0              2.0
# 44130             3804.0             3804.0              2.0
# 44131            28790.0            28790.0              2.0
#
#        NumberOfFeatures  NumberOfInstances  \
# 44089              11.0            16714.0
# 44090               9.0            20634.0
# 44091              12.0             2554.0
# 44120               8.0            38474.0
# 44121              11.0           566602.0
# 44122              27.0            10082.0
# 44123              17.0            13488.0
# 44124              21.0             5188.0
# 44125              11.0            13376.0
# 44126               8.0            10578.0
# 44127               6.0             3172.0
# 44128              51.0            72998.0
# 44129              25.0           940160.0
# 44130              21.0             7608.0
# 44131              55.0            57580.0
#
#        NumberOfInstancesWithMissingValues  NumberOfMissingValues  \
# 44089                                 0.0                    0.0
# 44090                                 0.0                    0.0
# 44091                                 0.0                    0.0
# 44120                                 0.0                    0.0
# 44121                                 0.0                    0.0
# 44122                                 0.0                    0.0
# 44123                                 0.0                    0.0
# 44124                                 0.0                    0.0
# 44125                                 0.0                    0.0
# 44126                                 0.0                    0.0
# 44127                                 0.0                    0.0
# 44128                                 0.0                    0.0
# 44129                                 0.0                    0.0
# 44130                                 0.0                    0.0
# 44131                                 0.0                    0.0
#
#        NumberOfNumericFeatures  NumberOfSymbolicFeatures
# 44089                     10.0                       1.0
# 44090                      8.0                       1.0
# 44091                     11.0                       1.0
# 44120                      7.0                       1.0
# 44121                     10.0                       1.0
# 44122                     26.0                       1.0
# 44123                     16.0                       1.0
# 44124                     20.0                       1.0
# 44125                     10.0                       1.0
# 44126                      7.0                       1.0
# 44127                      5.0                       1.0
# 44128                     50.0                       1.0
# 44129                     24.0                       1.0
# 44130                     20.0                       1.0
# 44131                     54.0                       1.0

# %%
"""
Count the number of data with both 'continuous' and 'categorical' variables, and the number of data with only 'categorical' variables.
"""

# see if NumberOfFeatures == NumberOfNumericFeatures + NumberOfSymbolicFeatures
# count the number of False, if any
temp = dlist['NumberOfFeatures'] == dlist['NumberOfNumericFeatures'] + dlist['NumberOfSymbolicFeatures']
print(temp.value_counts())

# count the number of rows where 'NumberOfNumericFeatures' or 'NumberOfSymbolicFeatures' is zero
print('number of rows where NumberOfNumericFeatures is zero:', len(dlist[dlist['NumberOfNumericFeatures'] == 0]))
# NumberOfSymbolicFeatures includes the class, so if it's 1, it means there's no categorical variable.
print('number of rows where NumberOfSymbolicFeatures is one:', len(dlist[dlist['NumberOfSymbolicFeatures'] == 1]))
# Out:
# True    15
# dtype: int64
# number of rows where NumberOfNumericFeatures is zero: 0
# number of rows where NumberOfSymbolicFeatures is one: 15

# %% [markdown]
# # 3. AutoML

# %%
benchmark_suite = openml.study.get_suite(suite_id = 271) 
benchmark_suite
# Out:
# OpenML Benchmark Suite
# ======================
# ID..............: 271
# Name............: AutoML Benchmark All Classification
# Status..........: in_preparation
# Main Entity Type: task
# Study URL.......: https://www.openml.org/s/271
# # of Data.......: 71
# # of Tasks......: 71
# Creator.........: https://www.openml.org/u/869
# Upload Time.....: 2020-11-19 20:52:19

# %%
# Task IDs and data IDs present in the benchmark suite.

print('number of tasks:', len(benchmark_suite.tasks))
print('task ids:', benchmark_suite.tasks)
print('')
print('number of data:', len(benchmark_suite.data))
print('data ids:', benchmark_suite.data)
# Out:
# number of tasks: 71
# task ids: [2073, 3945, 7593, 10090, 146818, 146820, 167120, 168350, 168757, 168784, 168868, 168909, 168910, 168911, 189354, 189355, 189356, 189922, 190137, 190146, 190392, 190410, 190411, 190412, 211979, 211986, 359953, 359954, 359955, 359956, 359957, 359958, 359959, 359960, 359961, 359962, 359963, 359964, 359965, 359966, 359967, 359968, 359969, 359970, 359971, 359972, 359973, 359974, 359975, 359976, 359977, 359979, 359980, 359981, 359982, 359983, 359984, 359985, 359986, 359987, 359988, 359989, 359990, 359991, 359992, 359993, 359994, 360112, 360113, 360114, 360975]
#
# number of data: 71
# data ids: [181, 1111, 1596, 1457, 40981, 40983, 23517, 1489, 31, 40982, 41138, 41163, 41164, 41143, 1169, 41167, 41147, 41158, 1487, 54, 41144, 41145, 41156, 41157, 41168, 4541, 1515, 188, 1464, 1494, 1468, 1049, 23, 40975, 12, 1067, 40984, 40670, 3, 40978, 4134, 40701, 1475, 4538, 4534, 41146, 41142, 40498, 40900, 40996, 40668, 4135, 1486, 41027, 1461, 1590, 41169, 41166, 41165, 40685, 41159, 41161, 41150, 41162, 42733, 42734, 42732, 42746, 42742, 42769, 43072]

# %%
data_ids_4 = benchmark_suite.data

# %%
"""
Get datasets
"""

dlist = datasets.list_datasets(data_id=benchmark_suite.data, output_format='dataframe')
dlist
# Out:
#          did                name  version uploader  status format  \
# 3          3            kr-vs-kp        1        1  active   ARFF
# 12        12       mfeat-factors        1        1  active   ARFF
# 23        23                 cmc        1        1  active   ARFF
# 31        31            credit-g        1        1  active   ARFF
# 54        54             vehicle        1        1  active   ARFF
# ...      ...                 ...      ...      ...     ...    ...
# 42734  42734        okcupid-stem        3    11601  active   arff
# 42742  42742        porto-seguro        3    11601  active   arff
# 42746  42746            KDDCup99        5    11601  active   arff
# 42769  42769               Higgs        3    11601  active   arff
# 43072  43072  KDDCup09-Upselling        3      869  active   arff
#
#        MajorityClassSize  MaxNominalAttDistinctValues  MinorityClassSize  \
# 3                 1669.0                          3.0             1527.0
# 12                 200.0                         10.0              200.0
# 23                 629.0                          4.0              333.0
# 31                 700.0                         10.0              300.0
# 54                 218.0                          4.0              199.0
# ...                  ...                          ...                ...
# 42734            36350.0                          NaN             4882.0
# 42742           573518.0                          NaN            21694.0
# 42746          2807886.0                          NaN                2.0
# 42769           529920.0                          NaN           470080.0
# 43072            46318.0                          NaN             3682.0
#
#        NumberOfClasses  NumberOfFeatures  NumberOfInstances  \
# 3                  2.0              37.0             3196.0
# 12                10.0             217.0             2000.0
# 23                 3.0              10.0             1473.0
# 31                 2.0              21.0             1000.0
# 54                 4.0              19.0              846.0
# ...                ...               ...                ...
# 42734              3.0              20.0            50789.0
# 42742              2.0              58.0           595212.0
# 42746             23.0              42.0          4898431.0
# 42769              2.0              29.0          1000000.0
# 43072              2.0           14892.0            50000.0
#
#        NumberOfInstancesWithMissingValues  NumberOfMissingValues  \
# 3                                     0.0                    0.0
# 12                                    0.0                    0.0
# 23                                    0.0                    0.0
# 31                                    0.0                    0.0
# 54                                    0.0                    0.0
# ...                                   ...                    ...
# 42734                             48622.0               154107.0
# 42742                            470281.0               846458.0
# 42746                                 0.0                    0.0
# 42769                                 0.0                    0.0
# 43072                             50000.0             19658569.0
#
#        NumberOfNumericFeatures  NumberOfSymbolicFeatures
# 3                          0.0                      37.0
# 12                       216.0                       1.0
# 23                         2.0                       8.0
# 31                         7.0                      14.0
# 54                        18.0                       1.0
# ...                        ...                       ...
# 42734                      2.0                      18.0
# 42742                     26.0                      32.0
# 42746                     32.0                      10.0
# 42769                     28.0                       1.0
# 43072                  14702.0                     190.0
#
# [71 rows x 16 columns]

# %%
# drop rows where 'name' contains 'mnist' or 'MNIST' or 'CIFAR'
dlist = dlist[~dlist['name'].str.contains('mnist', case=False)]
# dlist = dlist[~dlist['name'].str.contains('MNIST', case=False)]
# dlist = dlist[~dlist['name'].str.contains('CIFAR', case=False)]
dlist
# Out:
#          did                name  version uploader  status format  \
# 3          3            kr-vs-kp        1        1  active   ARFF
# 12        12       mfeat-factors        1        1  active   ARFF
# 23        23                 cmc        1        1  active   ARFF
# 31        31            credit-g        1        1  active   ARFF
# 54        54             vehicle        1        1  active   ARFF
# ...      ...                 ...      ...      ...     ...    ...
# 42734  42734        okcupid-stem        3    11601  active   arff
# 42742  42742        porto-seguro        3    11601  active   arff
# 42746  42746            KDDCup99        5    11601  active   arff
# 42769  42769               Higgs        3    11601  active   arff
# 43072  43072  KDDCup09-Upselling        3      869  active   arff
#
#        MajorityClassSize  MaxNominalAttDistinctValues  MinorityClassSize  \
# 3                 1669.0                          3.0             1527.0
# 12                 200.0                         10.0              200.0
# 23                 629.0                          4.0              333.0
# 31                 700.0                         10.0              300.0
# 54                 218.0                          4.0              199.0
# ...                  ...                          ...                ...
# 42734            36350.0                          NaN             4882.0
# 42742           573518.0                          NaN            21694.0
# 42746          2807886.0                          NaN                2.0
# 42769           529920.0                          NaN           470080.0
# 43072            46318.0                          NaN             3682.0
#
#        NumberOfClasses  NumberOfFeatures  NumberOfInstances  \
# 3                  2.0              37.0             3196.0
# 12                10.0             217.0             2000.0
# 23                 3.0              10.0             1473.0
# 31                 2.0              21.0             1000.0
# 54                 4.0              19.0              846.0
# ...                ...               ...                ...
# 42734              3.0              20.0            50789.0
# 42742              2.0              58.0           595212.0
# 42746             23.0              42.0          4898431.0
# 42769              2.0              29.0          1000000.0
# 43072              2.0           14892.0            50000.0
#
#        NumberOfInstancesWithMissingValues  NumberOfMissingValues  \
# 3                                     0.0                    0.0
# 12                                    0.0                    0.0
# 23                                    0.0                    0.0
# 31                                    0.0                    0.0
# 54                                    0.0                    0.0
# ...                                   ...                    ...
# 42734                             48622.0               154107.0
# 42742                            470281.0               846458.0
# 42746                                 0.0                    0.0
# 42769                                 0.0                    0.0
# 43072                             50000.0             19658569.0
#
#        NumberOfNumericFeatures  NumberOfSymbolicFeatures
# 3                          0.0                      37.0
# 12                       216.0                       1.0
# 23                         2.0                       8.0
# 31                         7.0                      14.0
# 54                        18.0                       1.0
# ...                        ...                       ...
# 42734                      2.0                      18.0
# 42742                     26.0                      32.0
# 42746                     32.0                      10.0
# 42769                     28.0                       1.0
# 43072                  14702.0                     190.0
#
# [70 rows x 16 columns]

# %%
"""
Count the number of data with both 'continuous' and 'categorical' variables, and the number of data with only 'categorical' variables.
"""

# see if NumberOfFeatures == NumberOfNumericFeatures + NumberOfSymbolicFeatures
# count the number of False, if any
temp = dlist['NumberOfFeatures'] == dlist['NumberOfNumericFeatures'] + dlist['NumberOfSymbolicFeatures']
print(temp.value_counts())

# count the number of rows where 'NumberOfNumericFeatures' or 'NumberOfSymbolicFeatures' is zero
print('number of rows where NumberOfNumericFeatures is zero:', len(dlist[dlist['NumberOfNumericFeatures'] == 0]))
# NumberOfSymbolicFeatures includes the class, so if it's 1, it means there's no categorical variable.
print('number of rows where NumberOfSymbolicFeatures is one:', len(dlist[dlist['NumberOfSymbolicFeatures'] == 1]))
# Out:
# True    70
# dtype: int64
# number of rows where NumberOfNumericFeatures is zero: 6
# number of rows where NumberOfSymbolicFeatures is one: 41

# %%
# Get tasks

tlist = openml.tasks.list_tasks(task_id=benchmark_suite.tasks, output_format="dataframe")
tlist
# Out:
#            tid                                ttid    did  \
# 2073      2073  TaskType.SUPERVISED_CLASSIFICATION    181
# 3945      3945  TaskType.SUPERVISED_CLASSIFICATION   1111
# 7593      7593  TaskType.SUPERVISED_CLASSIFICATION   1596
# 10090    10090  TaskType.SUPERVISED_CLASSIFICATION   1457
# 146818  146818  TaskType.SUPERVISED_CLASSIFICATION  40981
# ...        ...                                 ...    ...
# 359994  359994  TaskType.SUPERVISED_CLASSIFICATION  42732
# 360112  360112  TaskType.SUPERVISED_CLASSIFICATION  42746
# 360113  360113  TaskType.SUPERVISED_CLASSIFICATION  42742
# 360114  360114  TaskType.SUPERVISED_CLASSIFICATION  42769
# 360975  360975  TaskType.SUPERVISED_CLASSIFICATION  43072
#
#                            name                  task_type  status  \
# 2073                      yeast  Supervised Classification  active
# 3945         KDDCup09_appetency  Supervised Classification  active
# 7593                  covertype  Supervised Classification  active
# 10090   amazon-commerce-reviews  Supervised Classification  active
# 146818               Australian  Supervised Classification  active
# ...                         ...                        ...     ...
# 359994      sf-police-incidents  Supervised Classification  active
# 360112                 KDDCup99  Supervised Classification  active
# 360113             porto-seguro  Supervised Classification  active
# 360114                    Higgs  Supervised Classification  active
# 360975       KDDCup09-Upselling  Supervised Classification  active
#
#            estimation_procedure   evaluation_measures source_data  \
# 2073    10-fold Crossvalidation   predictive_accuracy         181
# 3945    10-fold Crossvalidation   predictive_accuracy        1111
# 7593    10-fold Crossvalidation                   NaN        1596
# 10090   10-fold Crossvalidation   predictive_accuracy        1457
# 146818  10-fold Crossvalidation                   NaN       40981
# ...                         ...                   ...         ...
# 359994  10-fold Crossvalidation   predictive_accuracy       42732
# 360112  10-fold Crossvalidation                   NaN       42746
# 360113  10-fold Crossvalidation                   NaN       42742
# 360114  10-fold Crossvalidation  area_under_roc_curve       42769
# 360975  10-fold Crossvalidation  area_under_roc_curve       43072
#
#                     target_feature  MajorityClassSize  \
# 2073    class_protein_localization                463
# 3945                     APPETENCY              49110
# 7593                         class             283301
# 10090                        Class                 30
# 146818                         A15                383
# ...                            ...                ...
# 359994                ViolentCrime            1945704
# 360112                      target            2807886
# 360113                      target             573518
# 360114                      target             529920
# 360975                   upselling              46318
#
#         MaxNominalAttDistinctValues  MinorityClassSize  NumberOfClasses  \
# 2073                           10.0                  5               10
# 3945                        15415.0                890                2
# 7593                            7.0               2747                7
# 10090                          50.0                 30               50
# 146818                         14.0                307                2
# ...                             ...                ...              ...
# 359994                          NaN             269319                2
# 360112                          NaN                  2               23
# 360113                          NaN              21694                2
# 360114                          NaN             470080                2
# 360975                          NaN               3682                2
#
#         NumberOfFeatures  NumberOfInstances  \
# 2073                   9               1484
# 3945                 231              50000
# 7593                  55             581012
# 10090              10001               1500
# 146818                15                690
# ...                  ...                ...
# 359994                 9            2215023
# 360112                42            4898431
# 360113                58             595212
# 360114                29            1000000
# 360975             14892              50000
#
#         NumberOfInstancesWithMissingValues  NumberOfMissingValues  \
# 2073                                     0                      0
# 3945                                 50000                8024152
# 7593                                     0                      0
# 10090                                    0                      0
# 146818                                   0                      0
# ...                                    ...                    ...
# 359994                                   0                      0
# 360112                                   0                      0
# 360113                              470281                 846458
# 360114                                   0                      0
# 360975                               50000               19658569
#
#         NumberOfNumericFeatures  NumberOfSymbolicFeatures
# 2073                          8                         1
# 3945                        192                        39
# 7593                         10                        45
# 10090                     10000                         1
# 146818                        6                         9
# ...                         ...                       ...
# 359994                        3                         6
# 360112                       32                        10
# 360113                       26                        32
# 360114                       28                         1
# 360975                    14702                       190
#
# [71 rows x 20 columns]

# %% [markdown]
# ## Collect

# %%
current_dir = os.getcwd()
save_path = current_dir + '/data/data_3/'

print(save_path)
# Out:
# c:\Users\lesga\OneDrive - UNIST\lab바탕화면\연구_STCC\_code\Dataset_OpenML/data/data_3/

# %%
dataset_dict = {}
did_automl = []

for did in tqdm(dlist['did']):
    # get dataset name from dlist
    name = dlist.loc[dlist['did']==did, 'name'].values[0]
    
    # get dataset from dlist
    odata = openml.datasets.get_dataset(did)
    X, y, categorical_indicator, attribute_names = odata.get_data(
                                                            target=odata.default_target_attribute, 
                                                            include_row_id=True,
                                                            include_ignore_attribute=True,
    )
    y.name = 'class' # the name of the 'y' variable
    
    if True in categorical_indicator: # Only data with categorical variables.
        
        # collect did
        did_automl.append(did)
        
        # get num, cat feature names
        num_feat_names = [attribute_names[i] for i in range(len(attribute_names)) if categorical_indicator[i]==False]
        cat_feat_names = [attribute_names[i] for i in range(len(attribute_names)) if categorical_indicator[i]==True]

        if len(num_feat_names) != 0: # Only data with continuous variables.

            # sort features names by num_feat_names and cat_feat_names
            X = X[num_feat_names+cat_feat_names] 
            # remove columns if cardinality is one
            X = X.loc[:, X.nunique() != 1]
            # remove columns if cardinality is num of rows (id)
            X = X.loc[:, X.nunique() != X.shape[0]]

            # get split from tlist
            task = openml.tasks.get_task(tlist[tlist['did']==did]['tid'].values[0])
            train_indices, test_indices = task.get_train_test_split_indices(repeat=0, fold=0, sample=0,)
            X_train, X_test, y_train, y_test = X.iloc[train_indices], X.iloc[test_indices], y.iloc[train_indices], y.iloc[test_indices]
            train = pd.concat([X_train, y_train], axis=1)
            test = pd.concat([X_test, y_test], axis=1)
            
            # create a folder path
            os.makedirs(save_path+f'{did}-{name}', exist_ok=True)
            # save train and test data
            train.to_csv(save_path+f'{did}-{name}/train.csv', index=False)
            test.to_csv(save_path+f'{did}-{name}/test.csv', index=False)
            
            # save cat feat names
            pd.DataFrame(cat_feat_names).to_csv(save_path+f'{did}-{name}/cat_feat_names.csv', index=False)
# Out:
#  94%|█████████▍| 66/70 [01:27<00:08,  2.03s/it]WARNING:openml.datasets.functions:Could not download file from http://openml1.win.tue.nl/dataset42742/dataset_42742.pq: Bucket does not exist or is private.
# WARNING:openml.datasets.functions:Could not download file from http://openml1.win.tue.nl/dataset42742/dataset_42742.pq: Bucket does not exist or is private.
#  96%|█████████▌| 67/70 [01:39<00:13,  4.63s/it]WARNING:openml.datasets.functions:Could not download file from http://openml1.win.tue.nl/dataset42746/dataset_42746.pq: Bucket does not exist or is private.
# WARNING:openml.datasets.functions:Could not download file from http://openml1.win.tue.nl/dataset42746/dataset_42746.pq: Bucket does not exist or is private.
#  97%|█████████▋| 68/70 [02:46<00:43, 21.67s/it]WARNING:openml.datasets.functions:Could not download file from http://openml1.win.tue.nl/dataset42769/dataset_42769.pq: Bucket does not exist or is private.
#  99%|█████████▊| 69/70 [02:49<00:16, 16.41s/it]WARNING:openml.datasets.functions:Could not download file from http://openml1.win.tue.nl/dataset43072/dataset_43072.pq: Bucket does not exist or is private.
# WARNING:openml.datasets.functions:Could not download file from http://openml1.win.tue.nl/dataset43072/dataset_43072.pq: Bucket does not exist or is private.
# 100%|██████████| 70/70 [18:24<00:00, 15.78s/it]

# %% [markdown]
# # 4. OpenML

# %%
"""
All data present in OpenML
"""

dlist = datasets.list_datasets(output_format='dataframe')
dlist
# Out:
#          did                        name  version uploader  status format  \
# 2          2                      anneal        1        1  active   ARFF
# 3          3                    kr-vs-kp        1        1  active   ARFF
# 4          4                       labor        1        1  active   ARFF
# 5          5                  arrhythmia        1        1  active   ARFF
# 6          6                      letter        1        1  active   ARFF
# ...      ...                         ...      ...      ...     ...    ...
# 45047  45047        Airlines_DepDelay_1M        6    26324  active   arff
# 45048  45048             medical_charges       12    26324  active   arff
# 45049  45049            MD_MIX_Mini_Copy        1     9186  active   arff
# 45050  45050  Amazon_Electronics_Dataset        1    31955  active   arff
# 45051  45051                  adult-test        1    31892  active   arff
#
#        MajorityClassSize  MaxNominalAttDistinctValues  MinorityClassSize  \
# 2                  684.0                          7.0                8.0
# 3                 1669.0                          3.0             1527.0
# 4                   37.0                          3.0               20.0
# 5                  245.0                         13.0                2.0
# 6                  813.0                         26.0              734.0
# ...                  ...                          ...                ...
# 45047                NaN                          NaN                NaN
# 45048                NaN                          NaN                NaN
# 45049               40.0                          NaN               40.0
# 45050                NaN                          NaN                NaN
# 45051            37155.0                          NaN            11687.0
#
#        NumberOfClasses  NumberOfFeatures  NumberOfInstances  \
# 2                  5.0              39.0              898.0
# 3                  2.0              37.0             3196.0
# 4                  2.0              17.0               57.0
# 5                 13.0             280.0              452.0
# 6                 26.0              17.0            20000.0
# ...                ...               ...                ...
# 45047              0.0               6.0          1000000.0
# 45048              0.0               4.0           163065.0
# 45049            706.0              69.0            28240.0
# 45050              NaN               3.0            10000.0
# 45051              2.0              15.0            48842.0
#
#        NumberOfInstancesWithMissingValues  NumberOfMissingValues  \
# 2                                   898.0                22175.0
# 3                                     0.0                    0.0
# 4                                    56.0                  326.0
# 5                                   384.0                  408.0
# 6                                     0.0                    0.0
# ...                                   ...                    ...
# 45047                                 0.0                    0.0
# 45048                                 0.0                    0.0
# 45049                             28240.0               665053.0
# 45050                                 0.0                    0.0
# 45051                              3620.0                 6465.0
#
#        NumberOfNumericFeatures  NumberOfSymbolicFeatures
# 2                          6.0                      33.0
# 3                          0.0                      37.0
# 4                          8.0                       9.0
# 5                        206.0                      74.0
# 6                         16.0                       1.0
# ...                        ...                       ...
# 45047                      6.0                       0.0
# 45048                      4.0                       0.0
# 45049                     45.0                       2.0
# 45050                      1.0                       2.0
# 45051                      6.0                       0.0
#
# [4961 rows x 16 columns]

# %%
"""
keep only latest version of datasets
"""

# capital letter to lower case in dlist['name']
dlist['name'] = dlist['name'].str.lower()
dlist_f = dlist.sort_values('version').drop_duplicates('name', keep='last')
dlist_f.shape
# Out:
# (3957, 16)

# %%
dlist_f
# Out:
#          did                                      name  version uploader  \
# 42178  42178                      telco-customer-churn        1     1140
# 42182  42182           lorenz_attractor_regime_changes        1    10283
# 42183  42183                             dataset_sales        1    10333
# 42186  42186                           juanfeldmaniris        1    10443
# 42188  42188                   premier_league_with_tda        1    10283
# ...      ...                                       ...      ...      ...
# 45012  45012                                      fifa       19    30127
# 44195  44195                                   weather       19    31897
# 42626  42626                                     train       24    11598
# 43035  43035  dgf_96f4164d-956d-4c1c-b161-68724eb0ccdc       27    26214
# 44344  44344                                      iris       52    30495
#
#        status format  MajorityClassSize  MaxNominalAttDistinctValues  \
# 42178  active   arff             5174.0                          NaN
# 42182  active   ARFF                NaN                          NaN
# 42183  active   ARFF                NaN                          NaN
# 42186  active   ARFF               50.0                          3.0
# 42188  active   ARFF                NaN                          NaN
# ...       ...    ...                ...                          ...
# 45012  active   arff                NaN                          NaN
# 44195  active   arff                9.0                          NaN
# 42626  active   arff                NaN                          NaN
# 43035  active   arff              398.0                          NaN
# 44344  active   arff               50.0                          NaN
#
#        MinorityClassSize  NumberOfClasses  NumberOfFeatures  \
# 42178             1869.0              2.0              20.0
# 42182                NaN              NaN               4.0
# 42183                NaN              0.0              15.0
# 42186               50.0              3.0               5.0
# 42188                NaN              NaN              20.0
# ...                  ...              ...               ...
# 45012                NaN              0.0              29.0
# 44195                5.0              2.0               5.0
# 42626                NaN              NaN              12.0
# 43035               10.0              5.0              57.0
# 44344               50.0              3.0               5.0
#
#        NumberOfInstances  NumberOfInstancesWithMissingValues  \
# 42178             7043.0                                 0.0
# 42182             4942.0                                 0.0
# 42183            10738.0                                 0.0
# 42186              150.0                                 0.0
# 42188             2565.0                                 0.0
# ...                  ...                                 ...
# 45012            19178.0                                 0.0
# 44195               14.0                                 0.0
# 42626              891.0                               708.0
# 43035              699.0                               699.0
# 44344              150.0                                 0.0
#
#        NumberOfMissingValues  NumberOfNumericFeatures  \
# 42178                    0.0                      3.0
# 42182                    0.0                      4.0
# 42183                    0.0                     15.0
# 42186                    0.0                      4.0
# 42188                    0.0                     20.0
# ...                      ...                      ...
# 45012                    0.0                     28.0
# 44195                    0.0                      2.0
# 42626                  866.0                      7.0
# 43035                 7889.0                     12.0
# 44344                    0.0                      4.0
#
#        NumberOfSymbolicFeatures
# 42178                       0.0
# 42182                       0.0
# 42183                       0.0
# 42186                       1.0
# 42188                       0.0
# ...                         ...
# 45012                       1.0
# 44195                       3.0
# 42626                       0.0
# 43035                      45.0
# 44344                       1.0
#
# [3957 rows x 16 columns]

# %%
"""
Exclude imgage and time-series data: 'mnist' or 'cifar' or 'forex' 'volcanoes' 'meta_album'
"""

dlist_f = dlist_f.loc[~dlist_f['name'].str.contains('mnist'), :]
dlist_f = dlist_f.loc[~dlist_f['name'].str.contains('cifar'), :]
dlist_f = dlist_f.loc[~dlist_f['name'].str.contains('forex'), :]
dlist_f = dlist_f.loc[~dlist_f['name'].str.contains('volcanoes'), :]
dlist_f = dlist_f.loc[~dlist_f['name'].str.contains('meta_album'), :]
dlist_f.shape
# Out:
# (3644, 16)

# %%
"""
Only data with numerical variables.
"""

dlist_f = dlist_f.loc[dlist_f['NumberOfNumericFeatures']>0, :]
dlist_f.shape
# Out:
# (24, 16)
# (3375, 16)

# %%
"""
Only data with more than 5000 samples.
"""

dlist_f = dlist_f.loc[dlist_f['NumberOfInstances'] >= 5000, :]
dlist_f.shape
# Out:
# (752, 16)

# %%
"""
Only data with classification tasks
"""

dlist_f = dlist_f.loc[dlist_f['NumberOfClasses'] > 0, :]
dlist_f.shape
# Out:
# (340, 16)
# (250, 16)

# %%
"""
Exclude the ones with too many NumberOfFeatures to eliminate images, text, composite data, etc
"""

# filter dataframe where NumberOfFeatures is less than 50
dlist_f_f = dlist_f.loc[dlist_f['NumberOfFeatures'] >= 150, :]
dlist_f = dlist_f.loc[dlist_f['NumberOfFeatures'] < 150, :]
dlist_f.shape
# Out:
# (214, 16)

# %%
dlist_f = dlist_f[dlist_f["NumberOfNumericFeatures"] > dlist_f["NumberOfSymbolicFeatures"]]

# %%
dlist_f = dlist_f[(dlist_f["MajorityClassSize"] / dlist_f["MinorityClassSize"] ) <= 5]

# %%
dlist_f = dlist_f[dlist_f["NumberOfClasses"] <= 5]

# %%
data_ids_5 = dlist_f.did.values

# %% [markdown]
# ## Collect

# %%
current_dir = os.getcwd()
save_path = current_dir + '/data/data_4_2/'

print(save_path)
# Out:
# /home/ubuntu/User/LEE/연구_신한/Dataset_OpenML/data/data_4_2/

# %%
dlist = dlist_f.copy()

# %%
dataset_dict = {}
did_dataset = []

for did in tqdm(dlist['did']):
    
    with warnings.catch_warnings(): 
        warnings.simplefilter("error")
    
        # get dataset name from dlist
        name = dlist.loc[dlist['did']==did, 'name'].values[0]
        
        # get dataset from dlist
        odata = openml.datasets.get_dataset(did)
        X, y, categorical_indicator, attribute_names = odata.get_data(
                                                                target=odata.default_target_attribute, 
                                                                include_row_id=True,
                                                                include_ignore_attribute=True,
        )
        y.name = 'class' # the name of the 'y' variable
        
        if True in categorical_indicator: # Only data with categorical variables.
            
            # collect did
            did_dataset.append(did)
            
            # get num, cat feature names
            num_feat_names = [attribute_names[i] for i in range(len(attribute_names)) if categorical_indicator[i]==False]
            cat_feat_names = [attribute_names[i] for i in range(len(attribute_names)) if categorical_indicator[i]==True]
            
            # sort features names by num_feat_names and cat_feat_names
            X = X[num_feat_names+cat_feat_names] 
            # remove columns if cardinality is one
            X = X.loc[:, X.nunique() != 1]
            # remove columns if cardinality is num of rows (id)
            X = X.loc[:, X.nunique() != X.shape[0]]
            
            # get split
            data = pd.concat([X, y], axis=1)
            split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=2022)
            train_indices, test_indices = next(split.split(data, data['class']))
            X_train, X_test, y_train, y_test = X.iloc[train_indices], X.iloc[test_indices], y.iloc[train_indices], y.iloc[test_indices]
            train = pd.concat([X_train, y_train], axis=1)
            test = pd.concat([X_test, y_test], axis=1)
            
            # create a folder path
            os.makedirs(save_path+f'{did}-{name}', exist_ok=True)
            # save train and test data
            train.to_csv(save_path+f'{did}-{name}/train.csv', index=False)
            test.to_csv(save_path+f'{did}-{name}/test.csv', index=False)
            
            # save cat feat names
            pd.DataFrame(cat_feat_names).to_csv(save_path+f'{did}-{name}/cat_feat_names.csv', index=False)
# Out:
#   0%|          | 0/73 [00:00<?, ?it/s]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset41228/dataset_41228.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset41228/dataset_41228.pq
#   3%|▎         | 2/73 [11:06<5:25:23, 274.99s/it] WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset40922/dataset_40922.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset40922/dataset_40922.pq
#   5%|▌         | 4/73 [11:09<1:58:51, 103.36s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset42178/dataset_42178.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset42178/dataset_42178.pq
#   7%|▋         | 5/73 [11:11<1:21:50, 72.21s/it] WARNING:root:Received uncompressed content from OpenML for https://api.openml.org/data/v1/download/22102432/WMO-Hurricane-Survival-Dataset.arff.
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset43607/dataset_43607.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset43607/dataset_43607.pq
#   8%|▊         | 6/73 [11:24<1:00:18, 54.01s/it]WARNING:root:Received uncompressed content from OpenML for https://api.openml.org/data/v1/download/22106811/NewspaperChurn.arff.
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44226/dataset_44226.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44226/dataset_44226.pq
#  10%|▉         | 7/73 [11:53<50:59, 46.35s/it]  WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset42477/dataset_42477.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset42477/dataset_42477.pq
#  11%|█         | 8/73 [12:18<43:17, 39.96s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset42468/dataset_42468.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset42468/dataset_42468.pq
#  12%|█▏        | 9/73 [21:25<3:26:06, 193.22s/it]WARNING:root:Received uncompressed content from OpenML for https://api.openml.org/data/v1/download/22102264/Medical-Appointment-No-Shows.arff.
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset43439/dataset_43439.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset43439/dataset_43439.pq
#  14%|█▎        | 10/73 [22:22<2:39:33, 151.97s/it]WARNING:root:Received uncompressed content from OpenML for https://api.openml.org/data/v1/download/22102314/Census-(Augmented).arff.
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset43489/dataset_43489.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset43489/dataset_43489.pq
#  15%|█▌        | 11/73 [42:10<7:59:20, 463.88s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1046/dataset_1046.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1046/dataset_1046.pq
#  18%|█▊        | 13/73 [42:31<3:51:16, 231.27s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset803/dataset_803.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset803/dataset_803.pq
#  19%|█▉        | 14/73 [42:42<2:42:21, 165.12s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1460/dataset_1460.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1460/dataset_1460.pq
#  21%|██        | 15/73 [42:51<1:54:28, 118.43s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1181/dataset_1181.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1181/dataset_1181.pq
#  23%|██▎       | 17/73 [1:01:52<5:05:24, 327.22s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1212/dataset_1212.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1212/dataset_1212.pq
#  25%|██▍       | 18/73 [1:20:36<8:01:06, 524.85s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1222/dataset_1222.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1222/dataset_1222.pq
#  26%|██▌       | 19/73 [1:20:52<5:52:30, 391.68s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1235/dataset_1235.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1235/dataset_1235.pq
#  30%|███       | 22/73 [1:31:53<3:35:24, 253.42s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1205/dataset_1205.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1205/dataset_1205.pq
#  33%|███▎      | 24/73 [1:37:17<2:38:35, 194.18s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1186/dataset_1186.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1186/dataset_1186.pq
#  34%|███▍      | 25/73 [1:52:02<5:18:10, 397.72s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset162/dataset_162.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset162/dataset_162.pq
#  37%|███▋      | 27/73 [1:54:53<2:59:21, 233.94s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset267/dataset_267.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset267/dataset_267.pq
#  38%|███▊      | 28/73 [2:00:05<3:12:55, 257.24s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset251/dataset_251.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset251/dataset_251.pq
#  41%|████      | 30/73 [2:00:47<1:38:23, 137.28s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset161/dataset_161.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset161/dataset_161.pq
#  47%|████▋     | 34/73 [2:03:35<33:21, 51.31s/it]   WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset152/dataset_152.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset152/dataset_152.pq
#  48%|████▊     | 35/73 [2:07:47<1:10:43, 111.67s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset153/dataset_153.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset153/dataset_153.pq
#  56%|█████▌    | 41/73 [2:15:30<38:37, 72.42s/it]   WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1507/dataset_1507.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1507/dataset_1507.pq
#  59%|█████▉    | 43/73 [2:16:54<29:39, 59.32s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1496/dataset_1496.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1496/dataset_1496.pq
#  60%|██████    | 44/73 [2:17:08<22:05, 45.71s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1502/dataset_1502.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset1502/dataset_1502.pq
#  62%|██████▏   | 45/73 [2:17:48<20:35, 44.14s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset752/dataset_752.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset752/dataset_752.pq
#  63%|██████▎   | 46/73 [2:21:26<43:18, 96.25s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset725/dataset_725.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset725/dataset_725.pq
#  64%|██████▍   | 47/73 [2:21:37<30:39, 70.76s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset727/dataset_727.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset727/dataset_727.pq
#  67%|██████▋   | 49/73 [2:21:54<15:16, 38.20s/it]WARNING:root:Received uncompressed content from OpenML for https://api.openml.org/data/v1/download/22106810/MembershipWoes.arff.
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44225/dataset_44225.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44225/dataset_44225.pq
#  68%|██████▊   | 50/73 [2:22:06<11:42, 30.53s/it]WARNING:root:Received uncompressed content from OpenML for https://api.openml.org/data/v1/download/22103185/credit.arff.
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44089/dataset_44089.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44089/dataset_44089.pq
#  70%|██████▉   | 51/73 [2:22:22<09:35, 26.14s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset979/dataset_979.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset979/dataset_979.pq
#  73%|███████▎  | 53/73 [2:22:44<05:59, 17.95s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset847/dataset_847.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset847/dataset_847.pq
#  74%|███████▍  | 54/73 [2:22:55<05:03, 15.96s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset843/dataset_843.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset843/dataset_843.pq
#  75%|███████▌  | 55/73 [2:23:10<04:39, 15.52s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset807/dataset_807.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset807/dataset_807.pq
#  77%|███████▋  | 56/73 [2:23:21<04:04, 14.41s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset816/dataset_816.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset816/dataset_816.pq
#  78%|███████▊  | 57/73 [2:23:33<03:37, 13.61s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset833/dataset_833.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset833/dataset_833.pq
#  79%|███████▉  | 58/73 [2:23:48<03:30, 14.06s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset881/dataset_881.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset881/dataset_881.pq
#  81%|████████  | 59/73 [2:24:21<04:34, 19.61s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset735/dataset_735.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset735/dataset_735.pq
#  82%|████████▏ | 60/73 [2:24:32<03:43, 17.22s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset819/dataset_819.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset819/dataset_819.pq
#  84%|████████▎ | 61/73 [2:24:43<03:02, 15.24s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44131/dataset_44131.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44131/dataset_44131.pq
#  85%|████████▍ | 62/73 [2:24:46<02:08, 11.65s/it]WARNING:root:Received uncompressed content from OpenML for https://api.openml.org/data/v1/download/22103186/california.arff.
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44090/dataset_44090.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44090/dataset_44090.pq
#  86%|████████▋ | 63/73 [2:25:02<02:07, 12.77s/it]WARNING:root:Received uncompressed content from OpenML for https://api.openml.org/data/v1/download/22103249/kdd_ipums_la_97-small.arff.
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44124/dataset_44124.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44124/dataset_44124.pq
#  88%|████████▊ | 64/73 [2:25:14<01:54, 12.67s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44128/dataset_44128.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44128/dataset_44128.pq
#  90%|█████████ | 66/73 [2:25:17<00:48,  6.90s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44161/dataset_44161.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44161/dataset_44161.pq
#  92%|█████████▏| 67/73 [2:25:55<01:36, 16.16s/it]WARNING:root:Received uncompressed content from OpenML for https://api.openml.org/data/v1/download/22103361/KDDCup09_upselling.arff.
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44186/dataset_44186.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44186/dataset_44186.pq
#  93%|█████████▎| 68/73 [2:26:18<01:30, 18.01s/it]WARNING:root:Received uncompressed content from OpenML for https://api.openml.org/data/v1/download/22103254/Higgs.arff.
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44129/dataset_44129.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44129/dataset_44129.pq
#  95%|█████████▍| 69/73 [2:39:50<17:05, 256.34s/it]WARNING:root:Received uncompressed content from OpenML for https://api.openml.org/data/v1/download/22103250/MagicTelescope.arff.
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44125/dataset_44125.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44125/dataset_44125.pq
#  96%|█████████▌| 70/73 [2:40:03<09:10, 183.46s/it]WARNING:root:Received uncompressed content from OpenML for https://api.openml.org/data/v1/download/22103251/bank-marketing.arff.
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44126/dataset_44126.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44126/dataset_44126.pq
#  97%|█████████▋| 71/73 [2:40:16<04:24, 132.09s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44157/dataset_44157.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44157/dataset_44157.pq
#  99%|█████████▊| 72/73 [2:40:22<01:34, 94.36s/it] WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44156/dataset_44156.pq
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),)': /dataset44156/dataset_44156.pq
# 100%|██████████| 73/73 [2:40:34<00:00, 131.98s/it]
